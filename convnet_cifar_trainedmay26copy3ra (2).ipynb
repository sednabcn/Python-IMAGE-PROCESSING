# %% [markdown]
# CONVNET FOR CIFAR 10 TO RECOGNIZE IMAGES

# %%
from __future__ import absolute_import
import os
import shutil
import random
import numpy as np
import keras 
from keras.layers import *
from keras.callbacks import EarlyStopping
# Out:
# Using TensorFlow backend.

# %%
#tensorflow 2.2.0-rc2
#!pip install tensorflow==2.2.0-rc2
# !pip install tensorflow==1.15
# Out:
# Requirement already satisfied: tensorflow==1.15 in /usr/local/lib/python3.6/dist-packages (1.15.0)
# Requirement already satisfied: keras-applications>=1.0.8 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15) (1.0.8)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15) (3.2.1)
# Requirement already satisfied: gast==0.2.2 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15) (0.2.2)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15) (1.1.0)
# Requirement already satisfied: numpy<2.0,>=1.16.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15) (1.18.4)
# Requirement already satisfied: grpcio>=1.8.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15) (1.29.0)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15) (0.34.2)
# Requirement already satisfied: google-pasta>=0.1.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15) (0.2.0)
# Requirement already satisfied: absl-py>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15) (0.9.0)
# Requirement already satisfied: protobuf>=3.6.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15) (3.10.0)
# Requirement already satisfied: tensorflow-estimator==1.15.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15) (1.15.1)
# Requirement already satisfied: astor>=0.6.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15) (0.8.1)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15) (1.12.0)
# Requirement already satisfied: tensorboard<1.16.0,>=1.15.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15) (1.15.0)
# Requirement already satisfied: wrapt>=1.11.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15) (1.12.1)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15) (1.1.2)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from keras-applications>=1.0.8->tensorflow==1.15) (2.10.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from protobuf>=3.6.1->tensorflow==1.15) (47.1.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.6/dist-packages (from tensorboard<1.16.0,>=1.15.0->tensorflow==1.15) (3.2.2)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.6/dist-packages (from tensorboard<1.16.0,>=1.15.0->tensorflow==1.15) (1.0.1)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /usr/local/lib/python3.6/dist-packages (from markdown>=2.6.8->tensorboard<1.16.0,>=1.15.0->tensorflow==1.15) (1.6.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.6/dist-packages (from importlib-metadata; python_version < "3.8"->markdown>=2.6.8->tensorboard<1.16.0,>=1.15.0->tensorflow==1.15) (3.1.0)

# %%
import tensorflow as tf

# %%
from keras import backend as K
from keras.models import Sequential
from keras.layers import Lambda, Layer, InputLayer
from keras.layers.convolutional import Conv2D
from keras.layers.convolutional import MaxPooling2D
from keras.layers.core import Activation
from keras.layers.core import Flatten
from keras.layers.core import Dense
from keras.datasets import cifar10 
from keras.utils import np_utils
from keras.constraints import maxnorm
from keras.optimizers import SGD
from keras.layers.core import Reshape
from keras.optimizers import SGD, RMSprop, Adam, Adadelta
from keras.layers.advanced_activations import LeakyReLU
from keras.preprocessing.image import ImageDataGenerator, array_to_img
import numpy as np
import matplotlib.pyplot as plt

# %%
K.common.set_image_dim_ordering('tf')

# %%
from keras.applications.vgg16 import VGG16

# %%
def reset_weights(model):
    for layer in model.layers:
        if isinstance(layer, tf.keras.Model): #if you're using a model as a layer
            reset_weights(layer) #apply function recursively
            continue

        #where are the initializers?
        if hasattr(layer, 'cell'):
            init_container = layer.cell
        else:
            init_container = layer

        for key, initializer in init_container.__dict__.items():
            if "initializer" not in key: #is this item an initializer?
                  continue #if no, skip it

            # find the corresponding variable, like the kernel or the bias
            if key == 'recurrent_initializer': #special case check
                var = getattr(init_container, 'recurrent_kernel')
            else:
                var = getattr(init_container, key.replace("_initializer", ""))

            var.assign(initializer(var.shape, var.dtype))
            #use the initializer

# %% [markdown]
# LABELS FROM CATEGORICAL TO NUMERICAL VALUES

# %%
nb_classes=10
class_names=['airplane','automobile','bird','cat','deer','dog','frog','horse','chip','truck']

# %% [markdown]
# MODEL

# %% [markdown]
# DATASET CIFAR_10 is a set of 60K images 32x32 pixels on 3 channels

# %%
#MODEL ARCHITECTURE
lr =0.0005

# we need a 60K x [32*32*3] shape as input to the CONVNET

input_shape=(32,32,3)

# %%
class VGG16L:
    @staticmethod 
    def build(input_shape,classes,lr=None):
              # load the VGG model
              vgg_conv =VGG16(weights='imagenet',include_top=False, input_shape = input_shape)
              # freeze the layers except the last 4 layers
              for layer in vgg_conv.layers[:-4]:
                       layer.trainable = False

              # Check the trainable status of the individual layers
              for layer in vgg_conv.layers:
                        print(layer, layer.trainable)
              # create the model
              model = Sequential()
              # add the vgg convolutional base model
              model.add(vgg_conv)
              # add new layers
              model.add(Flatten())
              model.add(Dense(512, activation='relu'))
              model.add(Dropout(0.5))
              model.add(Dense(classes, activation='softmax'))
              model.compile(loss='categorical_crossentropy',optimizer=Adam(lr),metrics=['accuracy'])
              return model

# %%
class CONVNET23:
    @staticmethod 
    def build(input_shape,classes,lr=None):
             model = Sequential()
             model.add(Conv2D(16, (3, 3), padding='same',input_shape=input_shape, activation='relu'))
             model.add(Conv2D(16, (3, 3), padding='same',activation='relu'))
             model.add(MaxPooling2D(pool_size=(2, 2)))
             model.add(Dropout(0.25))
             model.add(Conv2D(32, (3, 3), padding='same',activation='relu'))
             model.add(Conv2D(32, (3, 3),activation='relu'))
             model.add(MaxPooling2D(pool_size=(2, 2)))
             model.add(Dropout(0.25))
             model.add(Conv2D(64, (3, 3), padding='same',activation='relu'))
             model.add(Conv2D(64, (3, 3),activation='relu'))
             model.add(MaxPooling2D(pool_size=(2, 2)))
             model.add(Dropout(0.25))
             model.add(Flatten())
             model.add(Dense(512,activation='relu'))
             model.add(Dropout(0.5))
             model.add(Dense(classes))
             model.add(Activation('softmax'))
             model.compile(loss='categorical_crossentropy',optimizer=Adam(lr),metrics=['accuracy'])
             return model

# %% [markdown]
# MODEL

# %%
#model =VGG16L.build(input_shape,nb_classes,lr=lr)

# %%
model =CONVNET23.build(input_shape,nb_classes,lr=lr)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4070: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 32, 32, 16)        448
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 32, 32, 16)        2320
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 16, 16, 16)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 16, 16, 16)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 16, 16, 32)        4640
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 14, 14, 32)        9248
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 7, 7, 32)          0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 7, 7, 32)          0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 7, 7, 64)          18496
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 5, 5, 64)          36928
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 2, 2, 64)          0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 2, 2, 64)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               131584
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                5130
# _________________________________________________________________
# activation_1 (Activation)    (None, 10)                0
# =================================================================
# Total params: 208,794
# Trainable params: 208,794
# Non-trainable params: 0
# _________________________________________________________________

# %%
(X_train, y_train), (X_test, y_test) = cifar10.load_data()

# %% [markdown]
# DATA GENERATION

# %%
# augumenting
print("Augmenting training set images...")
#datagen = ImageDataGenerator(rotation_range=40,width_shift_range=0.2,height_shift_range=0.2,zoom_range=0.2,horizontal_flip=True,fill_mode='nearest',validation_split=0.2)
# Out:
# Augmenting training set images...

# %%
datagen = ImageDataGenerator(featurewise_center=True,featurewise_std_normalization=True,rotation_range=20,width_shift_range=0.2,
    height_shift_range=0.2,horizontal_flip=True)

# %%
def data_augmentation(X,Y,rows,cols,chan,classes,NUM_TO_AUGMENT):
      xtas, ytas =[],[]
      for i in range(X.shape[0]):
                num_aug = 0
                x = X[i] # (32, 32,3)
                y = Y[i]
                x = x.reshape((1,) + x.shape) # (1,32, 32,3)
                for x_aug,y_aug in datagen.flow(x, y,batch_size=1,save_to_dir='', save_prefix='traincifar', save_format='jpeg'):
                                            if num_aug < NUM_TO_AUGMENT:
                                                    xx_aug=np.asarray(x_aug).reshape(rows,cols,chan)
                                                    yy_aug=np.asarray(y_aug) 
                                                    xtas.append(xx_aug)
                                                    ytas.append(yy_aug)
                                                    num_aug+=1
                                            else:
                                                 break
      xtas=np.asarray(xtas)
      ytas=np.asarray(ytas)
      return xtas,ytas

# %%
#X_train,y_train=data_augmentation(X_tnag,y_tnag,32,32,3,nb_classes,4)

# %%
#[[X_train.shape,y_train.shape],[X_tnag.shape,y_tnag.shape]]

# %%
# convert class vectors to binary class matrices
#Y_train = np_utils.to_categorical(y_train, nb_classes)
Y_test = np_utils.to_categorical(y_test, nb_classes)

# %%
#from sklearn.model_selection import train_test_split
# Splitting train and validation

# %%
# X_train, X_val, y_train, y_val = train_test_split(X_nag, y_nag, test_size=0.2, random_state=42)

# %%
X_train = X_train.astype('float32')
##X_val =X_val.astype('float32')
X_test = X_test.astype('float32')
X_train /= 255
#X_val /=255
X_test /= 255

# %%
# convert class vectors to binary class matrices
Y_train = np_utils.to_categorical(y_train, nb_classes)
#Y_val= np_utils.to_categorical(y_val, nb_classes)

# %% [markdown]
# TRAINING

# %%
epochs=73
BATCH_SIZE = 32

# %%
## simple early stopping
#es = EarlyStopping(monitor='val_loss', mode='min', verbose=1)

# %%
history=model.fit(X_train,Y_train, batch_size=BATCH_SIZE, epochs=epochs, validation_split=0.2, verbose=1)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# Train on 40000 samples, validate on 10000 samples
# Epoch 1/73
# 40000/40000 [==============================] - 11s 272us/step - loss: 1.8078 - accuracy: 0.3239 - val_loss: 1.4450 - val_accuracy: 0.4728
# Epoch 2/73
# 40000/40000 [==============================] - 9s 225us/step - loss: 1.4321 - accuracy: 0.4774 - val_loss: 1.2672 - val_accuracy: 0.5407
# Epoch 3/73
# 40000/40000 [==============================] - 9s 226us/step - loss: 1.2696 - accuracy: 0.5393 - val_loss: 1.1089 - val_accuracy: 0.6015
# Epoch 4/73
# 40000/40000 [==============================] - 9s 227us/step - loss: 1.1709 - accuracy: 0.5788 - val_loss: 1.1027 - val_accuracy: 0.6009
# Epoch 5/73
# 40000/40000 [==============================] - 9s 225us/step - loss: 1.0939 - accuracy: 0.6109 - val_loss: 0.9755 - val_accuracy: 0.6458
# Epoch 6/73
# 40000/40000 [==============================] - 9s 231us/step - loss: 1.0274 - accuracy: 0.6338 - val_loss: 0.9014 - val_accuracy: 0.6767
# Epoch 7/73
# 40000/40000 [==============================] - 9s 227us/step - loss: 0.9766 - accuracy: 0.6526 - val_loss: 0.8462 - val_accuracy: 0.6964
# Epoch 8/73
# 40000/40000 [==============================] - 9s 236us/step - loss: 0.9311 - accuracy: 0.6739 - val_loss: 0.8163 - val_accuracy: 0.7103
# Epoch 9/73
# 40000/40000 [==============================] - 9s 232us/step - loss: 0.8972 - accuracy: 0.6838 - val_loss: 0.7987 - val_accuracy: 0.7181
# Epoch 10/73
# 40000/40000 [==============================] - 9s 235us/step - loss: 0.8687 - accuracy: 0.6948 - val_loss: 0.7448 - val_accuracy: 0.7353
# Epoch 11/73
# 40000/40000 [==============================] - 10s 240us/step - loss: 0.8313 - accuracy: 0.7086 - val_loss: 0.7307 - val_accuracy: 0.7399
# Epoch 12/73
# 40000/40000 [==============================] - 10s 238us/step - loss: 0.8150 - accuracy: 0.7150 - val_loss: 0.7494 - val_accuracy: 0.7338
# Epoch 13/73
# 40000/40000 [==============================] - 10s 239us/step - loss: 0.7940 - accuracy: 0.7218 - val_loss: 0.7212 - val_accuracy: 0.7470
# Epoch 14/73
# 40000/40000 [==============================] - 9s 228us/step - loss: 0.7744 - accuracy: 0.7265 - val_loss: 0.7385 - val_accuracy: 0.7401
# Epoch 15/73
# 40000/40000 [==============================] - 9s 227us/step - loss: 0.7592 - accuracy: 0.7327 - val_loss: 0.7068 - val_accuracy: 0.7531
# Epoch 16/73
# 40000/40000 [==============================] - 9s 227us/step - loss: 0.7395 - accuracy: 0.7423 - val_loss: 0.6688 - val_accuracy: 0.7636
# Epoch 17/73
# 40000/40000 [==============================] - 9s 228us/step - loss: 0.7261 - accuracy: 0.7459 - val_loss: 0.6635 - val_accuracy: 0.7656
# Epoch 18/73
# 40000/40000 [==============================] - 9s 227us/step - loss: 0.7139 - accuracy: 0.7497 - val_loss: 0.6510 - val_accuracy: 0.7723
# Epoch 19/73
# Epoch 59/73
# 40000/40000 [==============================] - 9s 222us/step - loss: 0.5382 - accuracy: 0.8141 - val_loss: 0.5800 - val_accuracy: 0.7994
# Epoch 60/73
# 40000/40000 [==============================] - 9s 224us/step - loss: 0.5376 - accuracy: 0.8100 - val_loss: 0.5927 - val_accuracy: 0.7981
# Epoch 61/73
# 40000/40000 [==============================] - 9s 224us/step - loss: 0.5303 - accuracy: 0.8139 - val_loss: 0.5797 - val_accuracy: 0.8030
# Epoch 62/73
# 40000/40000 [==============================] - 9s 224us/step - loss: 0.5288 - accuracy: 0.8149 - val_loss: 0.5810 - val_accuracy: 0.8006
# Epoch 63/73
# 40000/40000 [==============================] - 9s 223us/step - loss: 0.5303 - accuracy: 0.8110 - val_loss: 0.5996 - val_accuracy: 0.7998
# Epoch 64/73
# 40000/40000 [==============================] - 9s 221us/step - loss: 0.5337 - accuracy: 0.8126 - val_loss: 0.5802 - val_accuracy: 0.8002
# Epoch 65/73
# 40000/40000 [==============================] - 9s 223us/step - loss: 0.5290 - accuracy: 0.8124 - val_loss: 0.6047 - val_accuracy: 0.7971
# Epoch 66/73
# 40000/40000 [==============================] - 9s 225us/step - loss: 0.5303 - accuracy: 0.8124 - val_loss: 0.5839 - val_accuracy: 0.8077
# Epoch 67/73
# 40000/40000 [==============================] - 9s 224us/step - loss: 0.5227 - accuracy: 0.8139 - val_loss: 0.5976 - val_accuracy: 0.8012
# Epoch 68/73
# 40000/40000 [==============================] - 9s 222us/step - loss: 0.5263 - accuracy: 0.8157 - val_loss: 0.5868 - val_accuracy: 0.7976
# Epoch 69/73
# 40000/40000 [==============================] - 9s 224us/step - loss: 0.5315 - accuracy: 0.8102 - val_loss: 0.5748 - val_accuracy: 0.8055
# Epoch 70/73
# 40000/40000 [==============================] - 9s 223us/step - loss: 0.5176 - accuracy: 0.8163 - val_loss: 0.5865 - val_accuracy: 0.8003
# Epoch 71/73
# 40000/40000 [==============================] - 9s 221us/step - loss: 0.5157 - accuracy: 0.8176 - val_loss: 0.5815 - val_accuracy: 0.8015
# Epoch 72/73
# 40000/40000 [==============================] - 9s 223us/step - loss: 0.5171 - accuracy: 0.8185 - val_loss: 0.5733 - val_accuracy: 0.8026
# Epoch 73/73
# 40000/40000 [==============================] - 9s 224us/step - loss: 0.5190 - accuracy: 0.8173 - val_loss: 0.5892 - val_accuracy: 0.7999

# %%
score = model.evaluate(X_test, Y_test, verbose=1)
print('Test score:', score[0]*100)
print('Test accuracy:', score[1]*100)
# Out:
# 10000/10000 [==============================] - 1s 84us/step
# Test score: 60.95441319942474
# Test accuracy: 79.62999939918518

# %%
# list all data in history
print(history.history.keys())
# Out:
# dict_keys(['val_loss', 'val_accuracy', 'loss', 'accuracy'])

# %%
# summarize history for accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='lower right')
plt.grid(True)
plt.show()

# %%
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss History')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper right')
plt.show()

# %% [markdown]
# MODEL EVALUATION

# %%
score = model.evaluate(X_test, Y_test, verbose=1)
print('Test score:', score[0]*100)
print('Test accuracy:', score[1]*100)
# Out:
# 10000/10000 [==============================] - 1s 87us/step
# Test score: 60.95441319942474
# Test accuracy: 79.62999939918518

# %% [markdown]
# MODEL PREDICTION

# %%
predictions = model.predict(X_test)
predicted_labels=model.predict_classes(X_test)
#print([predictions[0],predicted_labels[0]])


#max= np.argmax(predictions[0])
#print(max)

#tt=y_test[0]
#print(tt)

# Plot the first 25 test images, their predicted label, and the true label
# Color correct predictions in green, incorrect predictions in red
plt.figure(figsize=(10,10))
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid('False')
    plt.imshow(X_test[i], cmap=plt.cm.binary)
    #plt.imshow(X_test[i], interpolation='nearest')
    predicted_label = np.argmax(predictions[i])
    true_label = y_test[i][0]
    if predicted_label == true_label:
      color = 'green'
    else:
      color = 'red'
    plt.xlabel("{} ({})".format(class_names[predicted_label], 
                                  class_names[true_label]),
                                  color=color)
plt.show()
plt.savefig("cifar10-convnet.pdf")

# %%
print('Finish')
# Out:
# Finish

# %% [markdown]
# from PIL import Image
# import numpy as np
#
# w, h = 512, 512
# data = np.zeros((h, w, 3), dtype=np.uint8)
# data[0:256, 0:256] = [255, 0, 0] # red patch in upper left
# img = Image.fromarray(data, 'RGB')
# img.save('my.png')
# img.show()
#
# from scipy.misc import toimage
# toimage(data).show()

# %%
#import keras
#vgg_model = keras.applications.vgg16.VGG16()
#model = keras.Sequential()
#model.add(vgg_model.layers[0])

# %%
history=model.fit(X_train,Y_train, batch_size=BATCH_SIZE, epochs=30, validation_split=0.2, verbose=1)
# Out:
# Train on 40000 samples, validate on 10000 samples
# Epoch 1/30
# 40000/40000 [==============================] - 9s 225us/step - loss: 0.5125 - accuracy: 0.8200 - val_loss: 0.5762 - val_accuracy: 0.8068
# Epoch 2/30
# 40000/40000 [==============================] - 9s 227us/step - loss: 0.5144 - accuracy: 0.8181 - val_loss: 0.5857 - val_accuracy: 0.8013
# Epoch 3/30
# 40000/40000 [==============================] - 9s 224us/step - loss: 0.5113 - accuracy: 0.8198 - val_loss: 0.5967 - val_accuracy: 0.7982
# Epoch 4/30
# 40000/40000 [==============================] - 9s 222us/step - loss: 0.5097 - accuracy: 0.8195 - val_loss: 0.5977 - val_accuracy: 0.7989
# Epoch 5/30
# 40000/40000 [==============================] - 9s 227us/step - loss: 0.5124 - accuracy: 0.8209 - val_loss: 0.5631 - val_accuracy: 0.8052
# Epoch 6/30
# 40000/40000 [==============================] - 9s 227us/step - loss: 0.5126 - accuracy: 0.8194 - val_loss: 0.5707 - val_accuracy: 0.8071
# Epoch 7/30
# 40000/40000 [==============================] - 9s 232us/step - loss: 0.5114 - accuracy: 0.8206 - val_loss: 0.5703 - val_accuracy: 0.8009
# Epoch 8/30
# 40000/40000 [==============================] - 9s 223us/step - loss: 0.5070 - accuracy: 0.8207 - val_loss: 0.5851 - val_accuracy: 0.7953
# Epoch 9/30
# 40000/40000 [==============================] - 9s 223us/step - loss: 0.5025 - accuracy: 0.8217 - val_loss: 0.5846 - val_accuracy: 0.8020
# Epoch 10/30
# 40000/40000 [==============================] - 9s 224us/step - loss: 0.5025 - accuracy: 0.8225 - val_loss: 0.5786 - val_accuracy: 0.8033
# Epoch 11/30
# 40000/40000 [==============================] - 9s 226us/step - loss: 0.5079 - accuracy: 0.8240 - val_loss: 0.5733 - val_accuracy: 0.8055
# Epoch 12/30
# 40000/40000 [==============================] - 9s 224us/step - loss: 0.5037 - accuracy: 0.8229 - val_loss: 0.5956 - val_accuracy: 0.7965
# Epoch 13/30
# 40000/40000 [==============================] - 9s 224us/step - loss: 0.5029 - accuracy: 0.8203 - val_loss: 0.5761 - val_accuracy: 0.8051
# Epoch 14/30
# 40000/40000 [==============================] - 9s 223us/step - loss: 0.4928 - accuracy: 0.8255 - val_loss: 0.5767 - val_accuracy: 0.8062
# Epoch 15/30
# 40000/40000 [==============================] - 9s 223us/step - loss: 0.5073 - accuracy: 0.8231 - val_loss: 0.5743 - val_accuracy: 0.8080
# Epoch 16/30
# 40000/40000 [==============================] - 9s 222us/step - loss: 0.5012 - accuracy: 0.8209 - val_loss: 0.5696 - val_accuracy: 0.8080
# Epoch 17/30
# 40000/40000 [==============================] - 9s 224us/step - loss: 0.5027 - accuracy: 0.8227 - val_loss: 0.5725 - val_accuracy: 0.8063
# Epoch 18/30
# 40000/40000 [==============================] - 9s 223us/step - loss: 0.4957 - accuracy: 0.8252 - val_loss: 0.5609 - val_accuracy: 0.8059
# Epoch 19/30
# 40000/40000 [==============================] - 9s 224us/step - loss: 0.5016 - accuracy: 0.8237 - val_loss: 0.5841 - val_accuracy: 0.7999
# Epoch 20/30
# 40000/40000 [==============================] - 9s 228us/step - loss: 0.4983 - accuracy: 0.8245 - val_loss: 0.5573 - val_accuracy: 0.8089
# Epoch 21/30
# 40000/40000 [==============================] - 9s 223us/step - loss: 0.4967 - accuracy: 0.8251 - val_loss: 0.5678 - val_accuracy: 0.8080
# Epoch 22/30
# 40000/40000 [==============================] - 9s 223us/step - loss: 0.4981 - accuracy: 0.8242 - val_loss: 0.5807 - val_accuracy: 0.8046
# Epoch 23/30
# 40000/40000 [==============================] - 9s 223us/step - loss: 0.4943 - accuracy: 0.8256 - val_loss: 0.5689 - val_accuracy: 0.8109
# Epoch 24/30
# 40000/40000 [==============================] - 9s 222us/step - loss: 0.4929 - accuracy: 0.8267 - val_loss: 0.5764 - val_accuracy: 0.8047
# Epoch 25/30
# 40000/40000 [==============================] - 9s 222us/step - loss: 0.4994 - accuracy: 0.8241 - val_loss: 0.5732 - val_accuracy: 0.8095
# Epoch 26/30
# 40000/40000 [==============================] - 9s 223us/step - loss: 0.4906 - accuracy: 0.8268 - val_loss: 0.6137 - val_accuracy: 0.7967
# Epoch 27/30
# 40000/40000 [==============================] - 9s 223us/step - loss: 0.4945 - accuracy: 0.8241 - val_loss: 0.5784 - val_accuracy: 0.8066
# Epoch 28/30
# 40000/40000 [==============================] - 9s 224us/step - loss: 0.4882 - accuracy: 0.8293 - val_loss: 0.5787 - val_accuracy: 0.8104
# Epoch 29/30
# 40000/40000 [==============================] - 9s 227us/step - loss: 0.4990 - accuracy: 0.8243 - val_loss: 0.5984 - val_accuracy: 0.7992
# Epoch 30/30
# 40000/40000 [==============================] - 9s 223us/step - loss: 0.4834 - accuracy: 0.8286 - val_loss: 0.5789 - val_accuracy: 0.8032

# %%
score = model.evaluate(X_test, Y_test, verbose=1)
print('Test score:', score[0]*100)
print('Test accuracy:', score[1]*100)
# Out:
# 10000/10000 [==============================] - 1s 84us/step
# Test score: 60.43483580112458
# Test accuracy: 79.39000129699707
